# %% [markdown]
# <a href="https://colab.research.google.com/github/liam-donaghy/news-money/blob/master/Kaggle_Load_to_GDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading Data

# %%
import csv
import zipfile
import csv
from datetime import date
from datetime import timedelta
from itertools import islice
import yfinance as yf
import torch
import os

# %% [markdown]
# ## Setting up Kaggle API

# %%
# !pip install kaggle

# %%
# !mkdir .kaggle

# %%
import json
token = {'username':'yousufl','key':'db83b25a8f0903f3b64f956a78c9654a'}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content/drive/My\ Drive/KaggleFinNews}
# Out:
# ...
# - path is now set to: {/content/drive/My Drive/KaggleFinNews}

# %%
#!kaggle datasets list

# %%
#!kaggle datasets list -s sentiment

# %%
# !kaggle datasets download -d jeet2016/us-financial-news-articles -p /content/drive/My\ Drive/KaggleFinNews
# Out:
# ...
#  99% 1.14G/1.15G [00:29<00:00, 49.8MB/s]
# 100% 1.15G/1.15G [00:29<00:00, 41.6MB/s]

# %%
# %cd content
# Out:
# /content

# %%
# %cd ..
# Out:
# /

# %%
# !mkdir KaggleFinNews

# %%
# %cd /content/drive/My Drive/KaggleFinNews
# Out:
# /content/drive/My Drive/KaggleFinNews

# %%
# !unzip \*.zip
# Out:
# Archive:  us-financial-news-articles.zip
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000001.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000002.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000010.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000048.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000083.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000101.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000102.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000103.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000104.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000105.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000415.json
#   inflating: 2018_01_112b52537b67659ad3609a234388c50a/blogs_0000416.json
# ...

# %%
# %cd drive
# Out:
# /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
